# %%
import numpy as np
import pandas as pd

# %%
from google_play_scraper import Sort, reviews_all

result = reviews_all(
    'com.disney.disneyplus',
    sleep_milliseconds=0, # defaults to 0
    lang='en', # defaults to 'en'
    country='us', # defaults to 'us'
    sort=Sort.NEWEST, # defaults to Sort.MOST_RELEVANT
    filter_score_with=5 # defaults to None(means all score)
)

# %%
df = pd.DataFrame(np.array(result),columns=['review'])


df = df.join(pd.DataFrame(df.pop('review').tolist()))
df= df.head(501)
df
# Out:
#                                  reviewId                 userName  \
# 0    cc2ef492-af9b-4128-8e7a-2995cffbec3d          Moorthy Moorthy
# 1    00062127-febd-40af-933b-fbee72089929           Haylie Materoa
# 2    025c4900-931b-4be1-b15b-94a887bf7298  Beauty 》 (Dalal & Hind)
# 3    1df8ab49-62d9-4891-ab9f-52f8823e1545         Christina Aubrey
# 4    82648cf6-d60f-4cc0-9338-c897b9cca5cd            Martise Fairy
# ..                                    ...                      ...
# 496  748af09f-073f-4c9e-9939-334955e03310            Cody Harrison
# 497  ea22a122-dc47-482a-87ac-4b6acf2f06ce              lori zuniga
# 498  5e9696a8-6dee-4c1b-8927-7d5a9f15db31          dbcjdn dnndndnd
# 499  c8f9706b-1029-4840-88ae-63f0d7940a8d            James Needham
# 500  1183195a-948e-447a-886f-f202a05ad0a3          Jayleen Alvarez
#
#                                              userImage  \
# 0    https://play-lh.googleusercontent.com/a/AItbvm...
# 1    https://play-lh.googleusercontent.com/a/AItbvm...
# 2    https://play-lh.googleusercontent.com/a-/AFdZu...
# 3    https://play-lh.googleusercontent.com/a/AItbvm...
# 4    https://play-lh.googleusercontent.com/a-/AFdZu...
# ..                                                 ...
# 496  https://play-lh.googleusercontent.com/a/AItbvm...
# 497  https://play-lh.googleusercontent.com/a/AItbvm...
# 498  https://play-lh.googleusercontent.com/a-/AFdZu...
# 499  https://play-lh.googleusercontent.com/a/AItbvm...
# 500  https://play-lh.googleusercontent.com/a/AItbvm...
#
#                                                content  score  thumbsUpCount  \
# 0                                            Very good      5              0
# 1                               can't wait to watch it      5              0
# 2                                            Your ugly      5              0
# 3                                              Owen W0      5              0
# 4              thank you will take care of this matter      5              0
# ..                                                 ...    ...            ...
# 496  they put all of the Star Wars movies and TV sh...      5              0
# 497  I've had this app for 2 years now and all of a...      5              0
# 498                                            Amazing      5              0
# 499  2/3rds the price of Netflix and way better stu...      5              0
# 500                                           Ecxelent      5              0
#
#     reviewCreatedVersion                  at replyContent repliedAt
# 0                   None 2022-09-04 15:26:24         None       NaT
# 1             2.10.0-rc1 2022-09-04 14:14:06         None       NaT
# 2                   None 2022-09-04 12:12:03         None       NaT
# 3              2.6.2-rc1 2022-09-04 12:04:22         None       NaT
# 4             2.10.0-rc1 2022-09-04 12:02:06         None       NaT
# ..                   ...                 ...          ...       ...
# 496           2.10.0-rc1 2022-08-25 07:15:01         None       NaT
# 497           2.10.0-rc1 2022-08-25 06:44:31         None       NaT
# 498                 None 2022-08-25 06:30:31         None       NaT
# 499           2.10.0-rc1 2022-08-25 06:27:04         None       NaT
# 500                 None 2022-08-25 06:06:32         None       NaT
#
# [501 rows x 10 columns]

# %%
df.isnull().any
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.any of      reviewId  userName  userImage  content  score  thumbsUpCount  \
# 0       False     False      False    False  False          False
# 1       False     False      False    False  False          False
# 2       False     False      False    False  False          False
# 3       False     False      False    False  False          False
# 4       False     False      False    False  False          False
# ..        ...       ...        ...      ...    ...            ...
# 496     False     False      False    False  False          False
# 497     False     False      False    False  False          False
# 498     False     False      False    False  False          False
# 499     False     False      False    False  False          False
# 500     False     False      False    False  False          False
#
#      reviewCreatedVersion     at  replyContent  repliedAt
# 0                    True  False          True       True
# 1                   False  False          True       True
# 2                    True  False          True       True
# 3                   False  False          True       True
# 4                   False  False          True       True
# ..                    ...    ...           ...        ...
# 496                 False  False          True       True
# 497                 False  False          True       True
# 498                  True  False          True       True
# 499                 False  False          True       True
# 500                  True  False          True       True
#
# [501 rows x 10 columns]>

# %%
df=df['content']

# %%
df.to_csv('reviews.csv')
# Out:
# 0                                              Very good
# 1                                 can't wait to watch it
# 2                                              Your ugly
# 3                                                Owen W0
# 4                thank you will take care of this matter
#                              ...
# 496    they put all of the Star Wars movies and TV sh...
# 497    I've had this app for 2 years now and all of a...
# 498                                              Amazing
# 499    2/3rds the price of Netflix and way better stu...
# 500                                             Ecxelent
# Name: content, Length: 501, dtype: object
