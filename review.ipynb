# %%
import re
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
plt.style.use('seaborn')
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

## change default settings
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', -1)

# %%
reviews = pd.read_csv('reviews.csv')
reviews.head()
# Out:
#    Unnamed: 0                                  content
# 0  0           Very good
# 1  1           can't wait to watch it
# 2  2           Your ugly
# 3  3           Owen W0
# 4  4           thank you will take care of this matter

# %%
mydata = reviews.drop('Unnamed: 0', axis=1)
mydata.head()
# Out:
#                                    content
# 0  Very good
# 1  can't wait to watch it
# 2  Your ugly
# 3  Owen W0
# 4  thank you will take care of this matter

# %%
mydata.rename(columns = {'content':'review'}, inplace = True)
mydata.head(5)
# Out:
#                                     review
# 0  Very good
# 1  can't wait to watch it
# 2  Your ugly
# 3  Owen W0
# 4  thank you will take care of this matter

# %%
# Define a function to clean the text
def clean(text):
# Removes all special characters and numericals leaving the alphabets
    text = re.sub('[^A-Za-z]+', ' ', text)
    return text

# Cleaning the text in the review column
mydata['Cleaned Reviews'] = mydata['review'].apply(clean)
mydata.head()
# Out:
#                                     review  \
# 0  Very good
# 1  can't wait to watch it
# 2  Your ugly
# 3  Owen W0
# 4  thank you will take care of this matter
#
#                            Cleaned Reviews
# 0  Very good
# 1  can t wait to watch it
# 2  Your ugly
# 3  Owen W
# 4  thank you will take care of this matter

# %% [markdown]
# ##### Tokenization, POS tagging, Stopwords removal

# %%
import nltk
nltk.download('omw-1.4')
nltk.download('point')
from nltk.tokenize import word_tokenize
from nltk import pos_tag
nltk.download('stopwords')
from nltk.corpus import stopwords
nltk.download('wordnet')
from nltk.corpus import wordnet
# Out:
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Error loading point: Package 'point' not found in index
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
stop_words = stopwords.words('english')
mydata['stopword_coun'] = mydata['review'].apply(lambda x: len([x for x in x.split() if x in stop_words]))
mydata['stopword_coun']
# Out:
# 0      0
# 1      2
# 2      0
# 3      0
# 4      4
#       ..
# 496    6
# 497    22
# 498    0
# 499    11
# 500    0
# Name: stopword_coun, Length: 501, dtype: int64

# %%
mydata.describe()
# Out:
#        stopword_coun
# count  501.000000
# mean   3.323353
# std    5.806482
# min    0.000000
# 25%    0.000000
# 50%    1.000000
# 75%    4.000000
# max    44.000000

# %%
mydata.head()
# Out:
#                                     review  \
# 0  Very good
# 1  can't wait to watch it
# 2  Your ugly
# 3  Owen W0
# 4  thank you will take care of this matter
#
#                            Cleaned Reviews  stopword_coun
# 0  Very good                                0
# 1  can t wait to watch it                   2
# 2  Your ugly                                0
# 3  Owen W                                   0
# 4  thank you will take care of this matter  4

# %%
# Lower case all words
mydata['review_lower'] = mydata['review'].apply(lambda x: " ".join(x.lower() for x in x.split()))

# %%
# Remove Punctuation
mydata['review_nopunc'] = mydata['review_lower'].str.replace('[^\w\s]', '')

# %%
# Import stopwords
from nltk.corpus import stopwords
stop_words = stopwords.words('english')

# Remove Stopwords
mydata['review_nopunc_nostop'] = mydata['review_nopunc'].apply(lambda x: " ".join(x for x in x.split() if x not in stop_words))
mydata.head()
# Out:
#                                     review  \
# 0  Very good
# 1  can't wait to watch it
# 2  Your ugly
# 3  Owen W0
# 4  thank you will take care of this matter
#
#                            Cleaned Reviews  stopword_coun  \
# 0  Very good                                0
# 1  can t wait to watch it                   2
# 2  Your ugly                                0
# 3  Owen W                                   0
# 4  thank you will take care of this matter  4
#
#                               review_lower  \
# 0  very good
# 1  can't wait to watch it
# 2  your ugly
# 3  owen w0
# 4  thank you will take care of this matter
#
#                              review_nopunc    review_nopunc_nostop
# 0  very good                                good
# 1  cant wait to watch it                    cant wait watch
# 2  your ugly                                ugly
# 3  owen w0                                  owen w0
# 4  thank you will take care of this matter  thank take care matter

# %%
# Return frequency of values
freq= pd.Series(" ".join(mydata['review_nopunc_nostop']).split()).value_counts()
freq
# Out:
# love           129
# app            98
# disney         96
# great          80
# good           69
#                ..
# hasnt          1
# glitched       1
# magnificent    1
# hwve           1
# ecxelent       1
# Length: 881, dtype: int64

# %%
other_stopwords = ['get', 'us', 'see', 'use', 'said', 'asked', 'day', 'go' \
  'even', 'ive', 'right', 'left', 'always', 'would', 'told', \
  'get', 'us', 'would', 'get', 'one', 'ive', 'go', 'even', \
  'also', 'ever', 'x', 'take', 'let' ]
mydata['lemma'] = mydata['review_nopunc_nostop'].apply(lambda x: "".join(" ".join(x for x in x.split() if x not in other_stopwords)))

# %%
mydata
# Out:
#                                                                                                                                                                                                  review  \
# 0    Very good
# 1    can't wait to watch it
# 2    Your ugly
# 3    Owen W0
# 4    thank you will take care of this matter
# ..                                       ...
# 496  they put all of the Star Wars movies and TV shows in storyline order
# 497  I've had this app for 2 years now and all of a sudden i can't watch anything cuz it keeps say error 83. I try and fix it but still nothing. My kids and myself love this app but now what do we do
# 498  Amazing
# 499  2/3rds the price of Netflix and way better stuff to watch even if you don't like Marvel or Star Wars because they also own Fox, ABC, others...
# 500  Ecxelent
#
#                                                                                                                                                                                  Cleaned Reviews  \
# 0    Very good
# 1    can t wait to watch it
# 2    Your ugly
# 3    Owen W
# 4    thank you will take care of this matter
# ..                                       ...
# 496  they put all of the Star Wars movies and TV shows in storyline order
# 497  I ve had this app for years now and all of a sudden i can t watch anything cuz it keeps say error I try and fix it but still nothing My kids and myself love this app but now what do we do
# 498  Amazing
# 499   rds the price of Netflix and way better stuff to watch even if you don t like Marvel or Star Wars because they also own Fox ABC others
# 500  Ecxelent
#
#      stopword_coun  \
# 0    0
# 1    2
# 2    0
# 3    0
# 4    4
# ..  ..
# 496  6
# 497  22
# 498  0
# 499  11
# 500  0
#
#                                                                                                                                                                                            review_lower  \
# 0    very good
# 1    can't wait to watch it
# 2    your ugly
# 3    owen w0
# 4    thank you will take care of this matter
# ..                                       ...
# 496  they put all of the star wars movies and tv shows in storyline order
# 497  i've had this app for 2 years now and all of a sudden i can't watch anything cuz it keeps say error 83. i try and fix it but still nothing. my kids and myself love this app but now what do we do
# 498  amazing
# 499  2/3rds the price of netflix and way better stuff to watch even if you don't like marvel or star wars because they also own fox, abc, others...
# 500  ecxelent
#
#                                                                                                                                                                                       review_nopunc  \
# 0    very good
# 1    cant wait to watch it
# 2    your ugly
# 3    owen w0
# 4    thank you will take care of this matter
# ..                                       ...
# 496  they put all of the star wars movies and tv shows in storyline order
# 497  ive had this app for 2 years now and all of a sudden i cant watch anything cuz it keeps say error 83 i try and fix it but still nothing my kids and myself love this app but now what do we do
# 498  amazing
# 499  23rds the price of netflix and way better stuff to watch even if you dont like marvel or star wars because they also own fox abc others
# 500  ecxelent
#
#                                                                                       review_nopunc_nostop  \
# 0    good
# 1    cant wait watch
# 2    ugly
# 3    owen w0
# 4    thank take care matter
# ..                      ...
# 496  put star wars movies tv shows storyline order
# 497  ive app 2 years sudden cant watch anything cuz keeps say error 83 try fix still nothing kids love app
# 498  amazing
# 499  23rds price netflix way better stuff watch even dont like marvel star wars also fox abc others
# 500  ecxelent
#
#                                                                                                  lemma
# 0    good
# 1    cant wait watch
# 2    ugly
# 3    owen w0
# 4    thank care matter
# ..                 ...
# 496  put star wars movies tv shows storyline order
# 497  app 2 years sudden cant watch anything cuz keeps say error 83 try fix still nothing kids love app
# 498  amazing
# 499  23rds price netflix way better stuff watch dont like marvel star wars fox abc others
# 500  ecxelent
#
# [501 rows x 7 columns]

# %%
mydata[['review','lemma']]
# Out:
#                                                                                                                                                                                                  review  \
# 0    Very good
# 1    can't wait to watch it
# 2    Your ugly
# 3    Owen W0
# 4    thank you will take care of this matter
# ..                                       ...
# 496  they put all of the Star Wars movies and TV shows in storyline order
# 497  I've had this app for 2 years now and all of a sudden i can't watch anything cuz it keeps say error 83. I try and fix it but still nothing. My kids and myself love this app but now what do we do
# 498  Amazing
# 499  2/3rds the price of Netflix and way better stuff to watch even if you don't like Marvel or Star Wars because they also own Fox, ABC, others...
# 500  Ecxelent
#
#                                                                                                  lemma
# 0    good
# 1    cant wait watch
# 2    ugly
# 3    owen w0
# 4    thank care matter
# ..                 ...
# 496  put star wars movies tv shows storyline order
# 497  app 2 years sudden cant watch anything cuz keeps say error 83 try fix still nothing kids love app
# 498  amazing
# 499  23rds price netflix way better stuff watch dont like marvel star wars fox abc others
# 500  ecxelent
#
# [501 rows x 2 columns]

# %% [markdown]
# ## Sentiment Analysis using TextBlob:

# %%
from textblob import TextBlob

def getSubjectivity(review):
    return TextBlob(review).sentiment.subjectivity
    # function to calculate polarity
def getPolarity(review):
        return TextBlob(review).sentiment.polarity
def analysis(score):
    if score < 0:
        return 'Negative'
    elif score == 0:
        return 'Neutral'
    else:
        return 'Positive'

# %%
fin_data = pd.DataFrame(mydata[['review', 'lemma']])

# %%
# fin_data['Subjectivity'] = fin_data['Lemma'].apply(getSubjectivity) 
fin_data['Polarity'] = fin_data['lemma'].apply(getPolarity) 
fin_data['Analysis'] = fin_data['Polarity'].apply(analysis)
fin_data
# Out:
#                                                                                                                                                                                                  review  \
# 0    Very good
# 1    can't wait to watch it
# 2    Your ugly
# 3    Owen W0
# 4    thank you will take care of this matter
# ..                                       ...
# 496  they put all of the Star Wars movies and TV shows in storyline order
# 497  I've had this app for 2 years now and all of a sudden i can't watch anything cuz it keeps say error 83. I try and fix it but still nothing. My kids and myself love this app but now what do we do
# 498  Amazing
# 499  2/3rds the price of Netflix and way better stuff to watch even if you don't like Marvel or Star Wars because they also own Fox, ABC, others...
# 500  Ecxelent
#
#                                                                                                  lemma  \
# 0    good
# 1    cant wait watch
# 2    ugly
# 3    owen w0
# 4    thank care matter
# ..                 ...
# 496  put star wars movies tv shows storyline order
# 497  app 2 years sudden cant watch anything cuz keeps say error 83 try fix still nothing kids love app
# 498  amazing
# 499  23rds price netflix way better stuff watch dont like marvel star wars fox abc others
# 500  ecxelent
#
#      Polarity  Analysis
# 0    0.70      Positive
# 1    0.00      Neutral
# 2   -0.70      Negative
# 3    0.00      Neutral
# 4    0.00      Neutral
# ..    ...          ...
# 496  0.00      Neutral
# 497  0.25      Positive
# 498  0.60      Positive
# 499  0.50      Positive
# 500  0.00      Neutral
#
# [501 rows x 4 columns]

# %%
tb_counts = fin_data.Analysis.value_counts()

tb_counts
# Out:
# Positive    398
# Neutral     93
# Negative    10
# Name: Analysis, dtype: int64
